# %% [markdown]
# TODO:
# - Mean/std of each of the 8 emotion pairs
# - A nice figure that shows the mean/std of emotion pairs
# - Count of word tokens in the descriptions
# - Average description length (in words)
# - Size of vocabulary for descriptions
# - Figure that shows distribution of words based on count
# - Ask Dr. K what he would like me to do in entries where the robot did nothing
# - Check rows where description is one word

# %% [markdown]
# DONE:
# - Check rows where all emotions labels are the same
# - Remove rows with NaN values
# - Remove rows with descriptions 'test' or 'stuff'

# %%
import pandas as pd
import numpy as np
import pickle
import nltk

# %% [markdown]
# # Data Cleaning Functions

# %%
def find_rows_with_same_emotion_labels(data):
    indices = []
    for index, row in data.iterrows():
        if row['Interst/Alarm'] == row['Confusion/Understanding'] == row['Frusteration/Relief'] == row['Sorrow/Joy'] == row['Anger/Gratitude'] == row['Fear/Hope'] == row['Boredom/Surprise'] == row['Disgust/Desire']:
            print(index, '\n', row)
            indices.append(index)
    return indices

# %%
def drop_row(data, index):
    return data.drop(index, axis=0)

# %%
def find_singleton_descriptions(data):
    indices = []
    for index, row in data.iterrows():
        if len(nltk.word_tokenize(str(row['Description']))) == 1:
            print(index, '\n', row['Timestamp'], '\n', row['Description'])
        indices.append(index)

# %%
def find_NaN_values(data):
    return np.where(pd.isnull(data))

# %%
def find_empty_values(data):
    np.where(data.applymap(lambda x: x == ''))

# %%
def find_rows_with_description(data, description):
    test_rows = data[data['Description']==description].index.tolist()
    return test_rows

# %%
cozmo_data = pd.read_csv('responses_cozmo_cleaned.csv')

# %%
cozmo_data = pd.read_pickle('./clean_cozmo_data.pkl')

# %%
cozmo_data.to_pickle('./clean_cozmo_data.pkl')

# %%
cozmo_data.to_csv('./cozmo_data_csv.csv')

# %%
cozmo_data
# Out:
#         Timestamp                                        Description  \
# 0    1.617917e+09              It went to investigate a thing it saw
# 1    1.619714e+09  drove forward for a bit and then turned to his...
# 2    1.619714e+09  just drove forward, made a little sound at the...
# 3    1.619714e+09  drove forward fairly quickly and then turned t...
# 4    1.619714e+09  looked down squinted eyes and then looked forw...
# ..            ...                                                ...
# 374  1.635358e+09  The robot shows relief, joy and a strong desir...
# 375  1.635358e+09  The robot seems to be angry or bored and surpr...
# 376  1.635358e+09  I did not actually understand the kind of emot...
# 377  1.635359e+09  Surprised and bored at the same time. It showe...
# 378  1.635359e+09  I did not really get the emotion the robot sho...
#
#      Interst/Alarm  Confusion/Understanding  Frusteration/Relief  Sorrow/Joy  \
# 0                1                        1                    3           3
# 1                2                        3                    3           3
# 2                2                        3                    3           3
# 3                1                        3                    3           3
# 4                2                        2                    3           3
# ..             ...                      ...                  ...         ...
# 374              1                        3                    5           5
# 375              4                        3                    2           2
# 376              3                        3                    3           3
# 377              3                        3                    2           3
# 378              3                        3                    3           3
#
#      Anger/Gratitude  Fear/Hope  Boredom/Surprise  Disgust/Desire
# 0                  3          4                 4               5
# 1                  3          3                 3               3
# 2                  3          3                 3               3
# 3                  4          4                 3               4
# 4                  3          3                 3               3
# ..               ...        ...               ...             ...
# 374                4          3                 3               5
# 375                1          3                 5               1
# 376                3          3                 3               3
# 377                1          2                 5               2
# 378                3          3                 3               3
#
# [377 rows x 10 columns]

# %%
find_rows_with_same_emotion_labels(cozmo_data)
# Out:
# 7
#  Timestamp                                                  1619714617.020491
# Description                drove forward a bit and then looked down. Repl...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 7, dtype: object
# 8
#  Timestamp                                                  1619714617.020491
# Description                drove forward a bit and then looked down. Repl...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 8, dtype: object
# 14
#  Timestamp                          1619715121.25564
# Description                moved forward and turned
# Interst/Alarm                                     3
# Confusion/Understanding                           3
# Frusteration/Relief                               3
# Sorrow/Joy                                        3
# Anger/Gratitude                                   3
# Fear/Hope                                         3
# Boredom/Surprise                                  3
# Disgust/Desire                                    3
# Name: 14, dtype: object
# 26
#  Timestamp                                   1620329983.106589
# Description                Cosmo didn't appear to do anything
# Interst/Alarm                                               3
# Confusion/Understanding                                     3
# Frusteration/Relief                                         3
# Sorrow/Joy                                                  3
# Anger/Gratitude                                             3
# Fear/Hope                                                   3
# Boredom/Surprise                                            3
# Disgust/Desire                                              3
# Name: 26, dtype: object
# 27
#  Timestamp                                                  1620330046.646846
# Description                Robot appears to have encounterd an error, it ...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 27, dtype: object
# 31
#  Timestamp                                                  1620330778.160888
# Description                Cosmo just kind of moved his head a little. No...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 31, dtype: object
# 32
#  Timestamp                                                  1620330845.463611
# Description                Cosmo moved his head down and let out a little...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 32, dtype: object
# 94
#  Timestamp                                            1633119469.579731
# Description                It performed no visible or auditory action.
# Interst/Alarm                                                        3
# Confusion/Understanding                                              3
# Frusteration/Relief                                                  3
# Sorrow/Joy                                                           3
# Anger/Gratitude                                                      3
# Fear/Hope                                                            3
# Boredom/Surprise                                                     3
# Disgust/Desire                                                       3
# Name: 94, dtype: object
# 183
#  Timestamp                                         1633621075.129493
# Description                the robot drove forward and to the right
# Interst/Alarm                                                     3
# Confusion/Understanding                                           3
# Frusteration/Relief                                               3
# Sorrow/Joy                                                        3
# Anger/Gratitude                                                   3
# Fear/Hope                                                         3
# Boredom/Surprise                                                  3
# Disgust/Desire                                                    3
# Name: 183, dtype: object
# 184
#  Timestamp                                           1633621158.002191
# Description                it spun 180 degrees and lowered its 'head'
# Interst/Alarm                                                       3
# Confusion/Understanding                                             3
# Frusteration/Relief                                                 3
# Sorrow/Joy                                                          3
# Anger/Gratitude                                                     3
# Fear/Hope                                                           3
# Boredom/Surprise                                                    3
# Disgust/Desire                                                      3
# Name: 184, dtype: object
# 186
#  Timestamp                                   1633621312.32395
# Description                drove forward a bit, nothing else
# Interst/Alarm                                              3
# Confusion/Understanding                                    3
# Frusteration/Relief                                        3
# Sorrow/Joy                                                 3
# Anger/Gratitude                                            3
# Fear/Hope                                                  3
# Boredom/Surprise                                           3
# Disgust/Desire                                             3
# Name: 186, dtype: object
# 189
#  Timestamp                                                  1633621529.252616
# Description                the robot did nothing besides move forwards ab...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 189, dtype: object
# 193
#  Timestamp                             1633621846.360249
# Description                it made a really short noise
# Interst/Alarm                                         3
# Confusion/Understanding                               3
# Frusteration/Relief                                   3
# Sorrow/Joy                                            3
# Anger/Gratitude                                       3
# Fear/Hope                                             3
# Boredom/Surprise                                      3
# Disgust/Desire                                        3
# Name: 193, dtype: object
# 200
#  Timestamp                                      1633622397.790242
# Description                it moved forward and lowered its arms
# Interst/Alarm                                                  3
# Confusion/Understanding                                        3
# Frusteration/Relief                                            3
# Sorrow/Joy                                                     3
# Anger/Gratitude                                                3
# Fear/Hope                                                      3
# Boredom/Surprise                                               3
# Disgust/Desire                                                 3
# Name: 200, dtype: object
# 222
#  Timestamp                  1633712814.356108
# Description                 nothing happened
# Interst/Alarm                              3
# Confusion/Understanding                    3
# Frusteration/Relief                        3
# Sorrow/Joy                                 3
# Anger/Gratitude                            3
# Fear/Hope                                  3
# Boredom/Surprise                           3
# Disgust/Desire                             3
# Name: 222, dtype: object
# 238
#  Timestamp                                           1633978931.483174
# Description                looked down and moved on fifth of a circle
# Interst/Alarm                                                       3
# Confusion/Understanding                                             3
# Frusteration/Relief                                                 3
# Sorrow/Joy                                                          3
# Anger/Gratitude                                                     3
# Fear/Hope                                                           3
# Boredom/Surprise                                                    3
# Disgust/Desire                                                      3
# Name: 238, dtype: object
# 240
#  Timestamp                             1633979097.292847
# Description                moved forward and left a bit
# Interst/Alarm                                         3
# Confusion/Understanding                               3
# Frusteration/Relief                                   3
# Sorrow/Joy                                            3
# Anger/Gratitude                                       3
# Fear/Hope                                             3
# Boredom/Surprise                                      3
# Disgust/Desire                                        3
# Name: 240, dtype: object
# 241
#  Timestamp                               1633979161.811781
# Description                moved his arms slightly higher
# Interst/Alarm                                           3
# Confusion/Understanding                                 3
# Frusteration/Relief                                     3
# Sorrow/Joy                                              3
# Anger/Gratitude                                         3
# Fear/Hope                                               3
# Boredom/Surprise                                        3
# Disgust/Desire                                          3
# Name: 241, dtype: object
# 242
#  Timestamp                  1633979220.902538
# Description                   lowers his arm
# Interst/Alarm                              3
# Confusion/Understanding                    3
# Frusteration/Relief                        3
# Sorrow/Joy                                 3
# Anger/Gratitude                            3
# Fear/Hope                                  3
# Boredom/Surprise                           3
# Disgust/Desire                             3
# Name: 242, dtype: object
# 246
#  Timestamp                  1633979500.159458
# Description                      turned left
# Interst/Alarm                              3
# Confusion/Understanding                    3
# Frusteration/Relief                        3
# Sorrow/Joy                                 3
# Anger/Gratitude                            3
# Fear/Hope                                  3
# Boredom/Surprise                           3
# Disgust/Desire                             3
# Name: 246, dtype: object
# 249
#  Timestamp                                                  1633979694.353548
# Description                long left turn followed by moving his arm upwa...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 249, dtype: object
# 252
#  Timestamp                                             1633979933.972687
# Description                arm and head movement in opposite directions
# Interst/Alarm                                                         3
# Confusion/Understanding                                               3
# Frusteration/Relief                                                   3
# Sorrow/Joy                                                            3
# Anger/Gratitude                                                       3
# Fear/Hope                                                             3
# Boredom/Surprise                                                      3
# Disgust/Desire                                                        3
# Name: 252, dtype: object
# 255
#  Timestamp                   1633980209.543078
# Description                didn't do anything
# Interst/Alarm                               3
# Confusion/Understanding                     3
# Frusteration/Relief                         3
# Sorrow/Joy                                  3
# Anger/Gratitude                             3
# Fear/Hope                                   3
# Boredom/Surprise                            3
# Disgust/Desire                              3
# Name: 255, dtype: object
# 259
#  Timestamp                  1634053638.939196
# Description                    Lifted loader
# Interst/Alarm                              3
# Confusion/Understanding                    3
# Frusteration/Relief                        3
# Sorrow/Joy                                 3
# Anger/Gratitude                            3
# Fear/Hope                                  3
# Boredom/Surprise                           3
# Disgust/Desire                             3
# Name: 259, dtype: object
# 265
#  Timestamp                                                  1634054504.091497
# Description                Nothing; just the slight sound of the robot mo...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 265, dtype: object
# 311
#  Timestamp                              1635186842.661699
# Description                The robot raised its arms up.
# Interst/Alarm                                          3
# Confusion/Understanding                                3
# Frusteration/Relief                                    3
# Sorrow/Joy                                             3
# Anger/Gratitude                                        3
# Fear/Hope                                              3
# Boredom/Surprise                                       3
# Disgust/Desire                                         3
# Name: 311, dtype: object
# 345
#  Timestamp                                      1635202655.75041
# Description                The robot showed no reaction at all.
# Interst/Alarm                                                 3
# Confusion/Understanding                                       3
# Frusteration/Relief                                           3
# Sorrow/Joy                                                    3
# Anger/Gratitude                                               3
# Fear/Hope                                                     3
# Boredom/Surprise                                              3
# Disgust/Desire                                                3
# Name: 345, dtype: object
# 346
#  Timestamp                                           1635202721.386349
# Description                The robot moved around and said something.
# Interst/Alarm                                                       5
# Confusion/Understanding                                             5
# Frusteration/Relief                                                 5
# Sorrow/Joy                                                          5
# Anger/Gratitude                                                     5
# Fear/Hope                                                           5
# Boredom/Surprise                                                    5
# Disgust/Desire                                                      5
# Name: 346, dtype: object
# 349
#  Timestamp                              1635203035.921143
# Description                It showed almost no reaction.
# Interst/Alarm                                          3
# Confusion/Understanding                                3
# Frusteration/Relief                                    3
# Sorrow/Joy                                             3
# Anger/Gratitude                                        3
# Fear/Hope                                              3
# Boredom/Surprise                                       3
# Disgust/Desire                                         3
# Name: 349, dtype: object
# 370
#  Timestamp                                                  1635357445.390338
# Description                I did not quite get the emotion the robot is t...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 370, dtype: object
# 376
#  Timestamp                                                  1635358406.496252
# Description                I did not actually understand the kind of emot...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 376, dtype: object
# 378
#  Timestamp                                                  1635358709.201428
# Description                I did not really get the emotion the robot sho...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 378, dtype: object
# [7,
#  8,
#  14,
#  26,
#  27,
#  31,
#  32,
#  94,
#  183,
#  184,
#  186,
#  189,
#  193,
#  200,
#  222,
#  238,
#  240,
#  241,
#  242,
#  246,
#  249,
#  252,
#  255,
#  259,
#  265,
#  311,
#  345,
#  346,
#  349,
#  370,
#  376,
#  378]

# %%
[143]
# Out:
# [143]

# %%
cozmo_data = drop_row(cozmo_data, 143)

# %%
find_NaN_values(cozmo_data)
# Out:
# (array([37]), array([1]))

# %%
cozmo_data.iloc[37]
# Out:
# Timestamp                                                   1620932710.61593
# Description                Moved right and dropped lift. Made sad/bored n...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    2
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 1
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           2
# Disgust/Desire                                                             3
# Name: 38, dtype: object

# %%
cozmo_data = drop_row(cozmo_data, 37)

# %%
find_empty_values(cozmo_data)

# %%
find_singleton_descriptions(cozmo_data)
# Out:
# 103
#  1633373656.0610828
#  interest
# 104
#  1633373733.466997
#  interest

# %%
find_rows_with_description(cozmo_data, 'test')
# Out:
# []

# %%
misty_data = pd.read_csv('responses_misty_cleaned.csv')

# %%
misty_data = pd.read_pickle('./clean_misty_data.pkl')

# %%
misty_data.to_pickle('./clean_misty_data.pkl')

# %%
misty_data.to_csv('./misty_data.csv')

# %%
misty_data
# Out:
#         Timestamp                                        Description  \
# 1    1.617916e+09       confused and asking for clarification almost
# 2    1.619713e+09  His eyes half closed, his head tilted up, his ...
# 3    1.619713e+09  eyes were half open, head tilted up and down s...
# 4    1.619713e+09  eyes were looking concerned to the left, then ...
# 5    1.619713e+09  one arm moved about halfway up twice head tilt...
# ..            ...                                                ...
# 435  1.635356e+09  This time Misty seem to be frustrated or bored...
# 436  1.635356e+09              Misty seems very surprised this time.
# 437  1.635356e+09  Misty seems angry as it seems to be looking at...
# 438  1.635357e+09  Misty looks interested and understanding. It s...
# 439  1.635357e+09  Misty seems to showed understanding, interest ...
#
#      Interst/Alarm  Confusion/Understanding  Frusteration/Relief  Sorrow/Joy  \
# 1                3                        2                    4           3
# 2                2                        4                    3           3
# 3                3                        3                    2           3
# 4                3                        2                    3           3
# 5                3                        3                    2           2
# ..             ...                      ...                  ...         ...
# 435              3                        1                    1           2
# 436              3                        3                    3           3
# 437              4                        3                    3           3
# 438              1                        5                    4           3
# 439              1                        5                    4           3
#
#      Anger/Gratitude  Fear/Hope  Boredom/Surprise  Disgust/Desire
# 1                  2          4                 1               1
# 2                  4          4                 3               5
# 3                  3          3                 1               3
# 4                  3          3                 4               3
# 5                  3          3                 2               3
# ..               ...        ...               ...             ...
# 435                1          3                 1               1
# 436                3          3                 5               3
# 437                1          3                 1               1
# 438                3          3                 3               5
# 439                4          3                 3               3
#
# [437 rows x 10 columns]

# %%
find_rows_with_same_emotion_labels(misty_data)
# Out:
# 76
#  Timestamp                  1630421538.523594
# Description                    Glitched out?
# Interst/Alarm                              3
# Confusion/Understanding                    3
# Frusteration/Relief                        3
# Sorrow/Joy                                 3
# Anger/Gratitude                            3
# Fear/Hope                                  3
# Boredom/Surprise                           3
# Disgust/Desire                             3
# Name: 76, dtype: object
# 89
#  Timestamp                                      1630448369.958236
# Description                the robot said hi and nodded its head
# Interst/Alarm                                                  3
# Confusion/Understanding                                        3
# Frusteration/Relief                                            3
# Sorrow/Joy                                                     3
# Anger/Gratitude                                                3
# Fear/Hope                                                      3
# Boredom/Surprise                                               3
# Disgust/Desire                                                 3
# Name: 89, dtype: object
# 110
#  Timestamp                      1630608163.293644
# Description                the robot was puzzled
# Interst/Alarm                                  1
# Confusion/Understanding                        1
# Frusteration/Relief                            1
# Sorrow/Joy                                     1
# Anger/Gratitude                                1
# Fear/Hope                                      1
# Boredom/Surprise                               1
# Disgust/Desire                                 1
# Name: 110, dtype: object
# 231
#  Timestamp                                   1633458592.521924
# Description                made noise, nodded head slightly.
# Interst/Alarm                                               3
# Confusion/Understanding                                     3
# Frusteration/Relief                                         3
# Sorrow/Joy                                                  3
# Anger/Gratitude                                             3
# Fear/Hope                                                   3
# Boredom/Surprise                                            3
# Disgust/Desire                                              3
# Name: 231, dtype: object
# 287
#  Timestamp                                                 1633620920.735452
# Description                the robot moved its left arm and nodded slightly
# Interst/Alarm                                                             3
# Confusion/Understanding                                                   3
# Frusteration/Relief                                                       3
# Sorrow/Joy                                                                3
# Anger/Gratitude                                                           3
# Fear/Hope                                                                 3
# Boredom/Surprise                                                          3
# Disgust/Desire                                                            3
# Name: 287, dtype: object
# 340
#  Timestamp                                                 1634053246.325546
# Description                said something like ah ah and looked to the side
# Interst/Alarm                                                             3
# Confusion/Understanding                                                   3
# Frusteration/Relief                                                       3
# Sorrow/Joy                                                                3
# Anger/Gratitude                                                           3
# Fear/Hope                                                                 3
# Boredom/Surprise                                                          3
# Disgust/Desire                                                            3
# Name: 340, dtype: object
# 381
#  Timestamp                                         1635184773.566632
# Description                The robot looked up and down repeatedly.
# Interst/Alarm                                                     3
# Confusion/Understanding                                           3
# Frusteration/Relief                                               3
# Sorrow/Joy                                                        3
# Anger/Gratitude                                                   3
# Fear/Hope                                                         3
# Boredom/Surprise                                                  3
# Disgust/Desire                                                    3
# Name: 381, dtype: object
# 382
#  Timestamp                                                  1635184825.354391
# Description                The robot looked up and down repeatedly. The l...
# Interst/Alarm                                                              3
# Confusion/Understanding                                                    3
# Frusteration/Relief                                                        3
# Sorrow/Joy                                                                 3
# Anger/Gratitude                                                            3
# Fear/Hope                                                                  3
# Boredom/Surprise                                                           3
# Disgust/Desire                                                             3
# Name: 382, dtype: object
# 408
#  Timestamp                    1635203895.071273
# Description                It nodded its head.
# Interst/Alarm                                3
# Confusion/Understanding                      3
# Frusteration/Relief                          3
# Sorrow/Joy                                   3
# Anger/Gratitude                              3
# Fear/Hope                                    3
# Boredom/Surprise                             3
# Disgust/Desire                               3
# Name: 408, dtype: object
# 411
#  Timestamp                           1635204041.137763
# Description                It showed little reaction.
# Interst/Alarm                                       3
# Confusion/Understanding                             3
# Frusteration/Relief                                 3
# Sorrow/Joy                                          3
# Anger/Gratitude                                     3
# Fear/Hope                                           3
# Boredom/Surprise                                    3
# Disgust/Desire                                      3
# Name: 411, dtype: object
# 412
#  Timestamp                           1635204041.137763
# Description                It showed little reaction.
# Interst/Alarm                                       3
# Confusion/Understanding                             3
# Frusteration/Relief                                 3
# Sorrow/Joy                                          3
# Anger/Gratitude                                     3
# Fear/Hope                                           3
# Boredom/Surprise                                    3
# Disgust/Desire                                      3
# Name: 412, dtype: object
# 414
#  Timestamp                   1635204460.843867
# Description                It waved its hand.
# Interst/Alarm                               3
# Confusion/Understanding                     3
# Frusteration/Relief                         3
# Sorrow/Joy                                  3
# Anger/Gratitude                             3
# Fear/Hope                                   3
# Boredom/Surprise                            3
# Disgust/Desire                              3
# Name: 414, dtype: object
# 415
#  Timestamp                   1635204460.843867
# Description                It waved its hand.
# Interst/Alarm                               3
# Confusion/Understanding                     3
# Frusteration/Relief                         3
# Sorrow/Joy                                  3
# Anger/Gratitude                             3
# Fear/Hope                                   3
# Boredom/Surprise                            3
# Disgust/Desire                              3
# Name: 415, dtype: object
# 417
#  Timestamp                    1635204655.543477
# Description                It nodded its head.
# Interst/Alarm                                3
# Confusion/Understanding                      3
# Frusteration/Relief                          3
# Sorrow/Joy                                   3
# Anger/Gratitude                              3
# Fear/Hope                                    3
# Boredom/Surprise                             3
# Disgust/Desire                               3
# Name: 417, dtype: object
# 418
#  Timestamp                                          1635204773.023
# Description                It slightly moved its right hand only.
# Interst/Alarm                                                   3
# Confusion/Understanding                                         3
# Frusteration/Relief                                             3
# Sorrow/Joy                                                      3
# Anger/Gratitude                                                 3
# Fear/Hope                                                       3
# Boredom/Surprise                                                3
# Disgust/Desire                                                  3
# Name: 418, dtype: object
# [76, 89, 110, 231, 287, 340, 381, 382, 408, 411, 412, 414, 415, 417, 418]

# %%
find_NaN_values(misty_data)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
find_empty_values(misty_data)

# %%
find_singleton_descriptions(misty_data)
# Out:
# 95
#  1630515062.8258655
#  confusion
# 98
#  1630520960.1284945
#  angery
# 108
#  1630601534.3583376
#  Sadness
# 121
#  1631134897.8837693
#  confused
#
# 122
#  1631134897.8837693
#  confused
#
# 123
#  1631134897.8837693
#  confused
#
# 124
#  1631134897.8837693
#  confused
#
# 125
#  1631134897.8837693
#  confused
#
# 126
#  1631134897.8837693
#  confused
#
# 175
#  1633371901.3289552
#  confusion
# 177
#  1633372138.351581
#  curiosity
# 181
#  1633372445.1713097
#  examination
# 185
#  1633372777.6040866
#  awestruk
# 186
#  1633372844.241636
#  awkward
# 192
#  1633373363.4952807
#  confusion
# 194
#  1633373531.5608878
#  confusion

# %%
misty_data = drop_row(misty_data, 139)

# %%
find_rows_with_description(misty_data, 'test')
# Out:
# []

# %%
misty_data = drop_row(misty_data, 0)

# %%
misty_data = drop_row(misty_data, 66)
